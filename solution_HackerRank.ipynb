# %%
#Say "Hello, World!" With Python

if __name__ == '__main__':
    print("Hello, World!")

# %%
#Python If-Else

import math
import os
import random
import re
import sys



if __name__ == '__main__':
    n = int(input().strip())
    if (((n%2)==0)and (n>20)) or (n==2) or (n==4):
        print("Not Weird")
    else:
        print("Weird")

# %%
#Python: Division

if __name__ == '__main__':
    a = int(input())
    b = int(input())
    x=a//b
    print(x)
    x=a/b
    print(x)

# %%
#Loops

if __name__ == '__main__':
    n = int(input())
    for i in range(0,n):
        x=i*i
        print(x)

# %%
#write a function

def is_leap(year):
    leap = False
    
    if (year%4==0):
        leap= True
    
    if (year%100==0)and(year%400!=0):
        leap= False 
        
    
        
    return leap

# %%
# Arithmetic Operators

if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a+b)
    print(a-b)
    print(a*b)

# %%
#print function

if __name__ == '__main__':
    n = int(input())
    x=range(1,n+1)
    print(*x,sep='')

# %%
#List Comprehensions

if __name__ == '__main__':
    x = int(input())
    y = int(input())
    z = int(input())
    n = int(input())
    
    print([[i,j,k] for i in range(x+1) for j in range(y+1) for k in range(z+1) if i+j+k!=n])

# %%
#Find the Runner-Up Score!

if __name__ == '__main__':
    n = int(input())
    arr = map(int, input().split())
    
    arr_sorted=sorted(arr, reverse=True)
   
    s=arr_sorted[0]
    a=0
    k=0
   
    while a<n:
        
        if arr_sorted[a]!=s:
            break
       
        a +=1
 
    print(arr_sorted[a])

# %%
#Nested Lists

if __name__ == '__main__':
    names = []
    scores = []
    for _ in range(int(input())):
        name = input()
        score = float(input())
        names.append(name)
        scores.append(score)
    
    n = len(names)  
    
    score_sorted = sorted(scores, reverse=False)
   
    s = score_sorted[0]
    a = 0
   
    while a < n:
        if score_sorted[a] != s:
            break
        a += 1
 
    s = score_sorted[a]
    
    name_1 = []
    
    for i in range(n):
        if scores[i] == s:
            name_1.append(names[i])
         
    name_1_sorted = sorted(name_1) 
    
    for j in name_1_sorted:
     print(j)

# %%
#Finding the percentage

if __name__ == '__main__':
    n = int(input())
    student_marks = {}
    for _ in range(n):
        name, *line = input().split()
        scores = list(map(float, line))
        student_marks[name] = scores
    query_name = input()
    
    
    voto = student_marks[query_name]
    media= sum(voto) / len(voto)
    media="{:.2f}".format(media)
    
    print(media)

# %%
#lists

if __name__ == '__main__':
    N = int(input())
    
    my_list = []

    for i in range(N):
        command = input().split()
        if command[0] == 'insert':
            my_list.insert(int(command[1]), int(command[2]))
        elif command[0] == 'print':
            print(my_list)
        elif command[0] == 'remove':
            my_list.remove(int(command[1]))
        elif command[0] == 'append':
            my_list.append(int(command[1]))
        elif command[0] == 'sort':
            my_list.sort()
        elif command[0] == 'pop':
            my_list.pop()
        elif command[0] == 'reverse':
            my_list.reverse()

# %%
#tuples

if __name__ == '__main__':
    n = int(input())
    integer_list = map(int, input().split())
    
    tupla = tuple(integer_list)
    r = hash(tupla)
    print(r)

# %%
#swap case

def swap_case(s):
    stringa_scambiata = ''
    for char in s:
        if char.islower():
            stringa_scambiata += char.upper()
        elif char.isupper():
            stringa_scambiata += char.lower()
        else:
            stringa_scambiata += char
    return stringa_scambiata

# %%
#String Split and Join

def split_and_join(line):
    divisa = line.split(" ")
    unita = "-".join(divisa)
    return unita

if __name__ == '__main__':
    line = input()
    result = split_and_join(line)
    print(result)

# %%
#What's Your Name?

def print_full_name(first, last):
    print(f"Hello {first} {last}! You just delved into python.")

# %%
#Mutations

def mutate_string(string, position, character):
    string = string[:position] + character + string[position+1:]
    return string

# %%
#Find a string

def count_substring(string, sub_string):
    n = 0
    for i in range(len(string) - len(sub_string) + 1):
        if string[i:i + len(sub_string)] == sub_string:
            n += 1
    return n

# %%
#String Validators

if __name__ == '__main__':
    s = input()
    
    print(any(c.isalnum() for c in s))
    print(any(c.isalpha() for c in s))
    print(any(c.isdigit() for c in s))
    print(any(c.islower() for c in s))
    print(any(c.isupper() for c in s))

# %%
#Text Wrap

def wrap(string, max_width):
    return textwrap.fill(string, max_width)

# %%
#Capitalize!

# Complete the solve function below.
def solve(s):
    parole = s.split(' ')
    c = [a if not a  else a[0].upper() + a[1:] for a in parole]
    return ' '.join(c)

# %%
#Introduction to Sets

def average(array):
    pesi = set(array)
    return sum(pesi) / len(pesi)

# %%
# No Idea!

if __name__ == '__main__':
    n, m = map(int, input().split())
    array = list(map(int, input().split()))
    set_a = set(map(int, input().split()))
    set_b = set(map(int, input().split()))

    happiness = 0
    for n in array:
        if n in set_a:
            happiness += 1
        elif n in set_b:
            happiness -= 1

    print(happiness)

# %%
#Symmetric Difference

if __name__ == '__main__':
    n = int(input())
    set_a = set(map(int, input().split()))
    m = int(input())
    set_b = set(map(int, input().split()))

    inter = set_a.intersection(set_b)
    union = set_a.union(set_b)
    diff = union.difference(inter)
    for n in sorted(diff):
        print(n)

# %%
#Set .add()

if __name__ == '__main__':
    n = int(input())
    stampe = set()
    for _ in range(n):
        stampe.add(input().strip())

    print(len(stampe))

# %%
#Set .union() Operation

if __name__ == '__main__':
    n = int(input())
    english = set(map(int, input().split()))
    b = int(input())
    french = set(map(int, input().split()))

    total = english.union(french)
    print(len(total))

# %%
#Set .intersection() Operation

if __name__ == '__main__':
    n = int(input())
    english = set(map(int, input().split()))
    b = int(input())
    french = set(map(int, input().split()))

    total = english.intersection(french)
    print(len(total))

# %%
#Set .difference() Operation

if __name__ == '__main__':
    n = int(input())
    english = set(map(int, input().split()))
    b = int(input())
    french = set(map(int, input().split()))

    only_english = english.difference(french)
    print(len(only_english))

# %%
#Set .symmetric_difference() Operation

if __name__ == '__main__':
    n = int(input())
    english = set(map(int, input().split()))
    b = int(input())
    french = set(map(int, input().split()))

    union = english.union(french)
    inter = english.intersection(french)
    students = union.difference(inter)
    print(len(students))

# %%
#Set Mutations

if __name__ == '__main__':
    n = int(input())
    s = set(map(int, input().split()))
    num_ops = int(input())

    for _ in range(num_ops):
        operation, length = input().split()
        other_set = set(map(int, input().split()))

        if operation == 'intersection_update':
            s.intersection_update(other_set)
        elif operation == 'update':
            s.update(other_set)
        elif operation == 'symmetric_difference_update':
            s.symmetric_difference_update(other_set)
        elif operation == 'difference_update':
            s.difference_update(other_set)
            
    print(sum(s))

# %%
#The Captain's Room

if __name__ == '__main__':
    k = int(input())
    room_list = list(map(int, input().split()))
    
    room = {}
    for r in room_list:
        if r in room:
          room[r] += 1
        else:
          room[r] = 1
    
    for r, c in room.items():
        if c == 1:
           print(r)
           break

# %%
#Check Subset

if __name__ == '__main__':
    t = int(input())
    for _ in range(t):
        n_a = int(input())
        a = set(map(int, input().split()))
        n_b = int(input())
        b = set(map(int, input().split()))
        s=a.difference(b)
        if not s:
          print(True)
        else:
          print(False)

# %%
#Check Strict Superset

if __name__ == '__main__':
    set_A = set(map(int, input().split()))
    n = int(input())
    strict_superset = True

    for _ in range(n):
        set_B = set(map(int, input().split()))
        if not set_A.union(set_B) == set_A and len(set_A) > len(set_B):
            strict_superset = False
            break

    print(strict_superset)

# %%
#collections.Counter()

from collections import Counter

if __name__ == '__main__':
    num_shoes = int(input())
    shoe_sizes = Counter(map(int, input().split()))
    num_customers = int(input())

    total_earnings = 0

    for _ in range(num_customers):
        size, price = map(int, input().split())
        if shoe_sizes[size] > 0:
            total_earnings += price
            shoe_sizes[size] -= 1

    print(total_earnings)

# %%
#Collections.namedtuple()

from collections import namedtuple
from statistics import mean

if __name__ == '__main__':
    n = int(input())
    fields = input().split()
    Student = namedtuple('Student', fields)
    total = 0
    for _ in range(n):
        student = Student(*input().split())
        total += int(student.MARKS)
    print("{:.2f}".format(total/n))

# %%
#Word Order

from collections import OrderedDict

if __name__ == '__main__':
    n = int(input())
    lista = OrderedDict()

    for _ in range(n):
        word = input().strip()
        if word in lista:
            lista[word] += 1
        else:
            lista[word] = 1

    print(len(lista))
    print(*lista.values())

# %%
#Collections.deque()

from collections import deque

if __name__ == '__main__':
    d = deque()
    n = int(input())
    for _ in range(n):
        operation = input().split()
        if operation[0] == 'append':
            d.append(operation[1])
        elif operation[0] == 'appendleft':
            d.appendleft(operation[1])
        elif operation[0] == 'pop':
            d.pop()
        elif operation[0] == 'popleft':
            d.popleft()
    print(' '.join(d))

# %%
#Arrays 

def arrays(arr):
    a = numpy.array(arr, float)
    return a[::-1]

# %%
#Shape and Reshape

import numpy

input_line = input().split()
integers = list(map(int, input_line))

array = numpy.array(integers).reshape(3, 3)

print(array)

# %%
#Transpose and Flatten

import numpy

n, m = map(int, input().split())

matrix = []
for _ in range(n):
    row = list(map(int, input().split()))
    matrix.append(row)

array = numpy.array(matrix)

print(numpy.transpose(array))
print(array.flatten())

# %%
#Concatenate

import numpy

n, m, p = map(int, input().split())

arr1 = []
for _ in range(n):
    row = list(map(int, input().split()))
    arr1.append(row)

arr2 = []
for _ in range(m):
    row = list(map(int, input().split()))
    arr2.append(row)

matrix1 = numpy.array(arr1)
matrix2 = numpy.array(arr2)

result = numpy.concatenate((matrix1, matrix2), axis=0)

print(result)

# %%
#Eye and Identity

import numpy

numpy.set_printoptions(legacy='1.13')

n, m = map(int, input().split())

identity_array = numpy.eye(n, m)

print(identity_array)

# %%
#Floor, Ceil and Rint

import numpy

numpy.set_printoptions(legacy='1.13')

array = numpy.array(input().split(), float)

print(numpy.floor(array))
print(numpy.ceil(array))
print(numpy.rint(array))

# %%
#Sum and Prod

import numpy

n, m = map(int, input().split())
array = numpy.array([input().split() for _ in range(n)], int)

sum_0 = numpy.sum(array, axis=0)

result = numpy.prod(sum_0)

print(result)

# %%
#Min and Max

import numpy

n, m = map(int, input().split())
array = numpy.array([input().split() for _ in range(n)], int)

min_1 = numpy.min(array, axis=1)

result = numpy.max(min_1)

print(result)

# %%
#Dot and Cross

import numpy

n = int(input())

a = numpy.array([input().split() for _ in range(n)], int)

b = numpy.array([input().split() for _ in range(n)], int)


result = numpy.dot(a, b)

print(result)

# %%
#Inner and Outer

import numpy

a = numpy.array(input().split(), int)
b = numpy.array(input().split(), int)

print(numpy.inner(a, b))

print(numpy.outer(a, b))

# %%
#Polynomials 

import numpy

coeff = list(map(float, input().split()))


x = float(input())

result = numpy.polyval(coeff, x)
print(result)

# %%
#Linear Algebra

import numpy

n = int(input())

matrix = []
for _ in range(n):
    row = list(map(float, input().split()))
    matrix.append(row)


det = numpy.linalg.det(matrix)

print(round(det, 2))
